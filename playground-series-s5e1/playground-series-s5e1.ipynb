# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
#  Academic_Artifacts/                     'Google Earth'/    RT_df.pkl
#  Colab_Notebooks/                         Kaggle/           RT_transformer_df.pkl
# 'Denver, CO -- December 2024 Trip.gdoc'   Model_Research/   SpatialFormer/

# %% [markdown]
# This guide explains how to upload files directly from your Google Colab environment to Kaggle using the Kaggle API.
#
# ---
#
# ## 🛠️ Prerequisites
#
# 1. **Google Colab Account:** Ensure you have access to Google Colab.
# 2. **Kaggle Account:** Log in or create an account at [Kaggle](https://www.kaggle.com/).
# 3. **Kaggle API Key:** Download your API key:
#    - Go to [Account Settings](https://www.kaggle.com/account).
#    - Click **Create New API Token**.
#    - A file named `kaggle.json` will be downloaded.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-795c7a52-df18-4aec-9fa2-8fcb0e23a74c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-795c7a52-df18-4aec-9fa2-8fcb0e23a74c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p /root/.kaggle/

# %%
import shutil
shutil.move("kaggle.json", "/root/.kaggle/")
# Out:
# '/root/.kaggle/kaggle.json'

# %%
rm /root/.kaggle/kaggle.json

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %% [markdown]
# This ensures appropriate access

# %%
# !kaggle datasets list
# Out:
# ref                                                           title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# anandshaw2001/netflix-movies-and-tv-shows                     Netflix Movies and TV Shows                       1MB  2025-01-03 10:33:01           5780        166  1.0
# ahmedmohamed2003/cafe-sales-dirty-data-for-cleaning-training  Cafe Sales - Dirty Data for Cleaning Training   111KB  2025-01-17 19:49:39            986         23  1.0
# ashaychoudhary/comprehensive-lung-cancer-dataset              Comprehensive Lung Cancer Dataset                10MB  2025-01-16 04:28:26            885         26  1.0
# ...

# %%
# !kaggle competitions download playground-series-s5e1
# Out:
# ...
#   0% 0.00/2.26M [00:00<?, ?B/s]
# 100% 2.26M/2.26M [00:00<00:00, 71.2MB/s]

# %%
import zipfile

# Replace 'data.zip' with your ZIP file's name
with zipfile.ZipFile("playground-series-s5e1.zip", "r") as zip_ref:
    zip_ref.extractall("/content")

# %%
# !ls /content
# Out:
# gdrive	sample_data  sample_submission.csv  test.csv  train.csv

# %% [markdown]
# # 📊 Train Dataset Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) is a critical step in understanding and preparing your dataset for modeling. This guide walks through common EDA steps for analyzing a training dataset.
#
# ---

# %%
# Out:
#   File "<ipython-input-28-5f5cd7b43b72>", line 3
#     Exploratory Data Analysis (EDA) is a critical step in understanding and preparing your dataset for modeling. This guide walks through common EDA steps for analyzing a training dataset.
#                 ^
# SyntaxError: invalid syntax
