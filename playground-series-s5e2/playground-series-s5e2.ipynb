# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
#  Academic_Artifacts/                      Kaggle/                      RT_transformer_df.pkl
#  Colab_Notebooks/                         Model_Research/              SpatialFormer/
# 'Denver, CO -- December 2024 Trip.gdoc'   playground-series-s5e1.zip
# 'Google Earth'/                           RT_df.pkl

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-afac1695-af4d-4a7a-8544-663c6060c0a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-afac1695-af4d-4a7a-8544-663c6060c0a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p /root/.kaggle/

# %%
import shutil
shutil.move("kaggle.json", "/root/.kaggle/")
# Out:
# '/root/.kaggle/kaggle.json'

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %% [markdown]
# This ensures appropriate access

# %%
# !kaggle datasets list
# Out:
# ref                                                               title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# anandshaw2001/netflix-movies-and-tv-shows                         Netflix Movies and TV Shows                          1MB  2025-01-03 10:33:01          10166        271  1.0
# ankushpanday1/global-road-accidents-dataset                       Global Road Accidents Dataset                       12MB  2025-01-25 04:22:29           1272         37  1.0
# ashaychoudhary/anxiety-attack-factors-symptoms-and-severity       Anxiety Attack : Factors, Symptoms, and Severity   244KB  2025-01-19 11:56:21           2129         43  1.0
# ...

# %%
# !kaggle competitions download playground-series-s5e2
# Out:
# playground-series-s5e1.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

# Replace 'data.zip' with your ZIP file's name
with zipfile.ZipFile("playground-series-s5e1.zip", "r") as zip_ref:
    zip_ref.extractall("/content")

# %%
# !ls /content
# Out:
# gdrive	sample_data  sample_submission.csv  test.csv  train.csv

# %% [markdown]
# # 📊 Train Dataset Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) is a critical step in understanding and preparing your dataset for modeling. This guide walks through common EDA steps for analyzing a training dataset.
#
# ---

# %%
# Out:
#   File "<ipython-input-28-5f5cd7b43b72>", line 3
#     Exploratory Data Analysis (EDA) is a critical step in understanding and preparing your dataset for modeling. This guide walks through common EDA steps for analyzing a training dataset.
#                 ^
# SyntaxError: invalid syntax
